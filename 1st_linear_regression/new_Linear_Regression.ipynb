# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dataset = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/ML_DA/new_household_price - Sheet1.csv")

# %%
dataset
# Out:
#      Area      Price
# 0     500    2000000
# 1     550    2500000
# 2     600    3000000
# 3     650    3500000
# 4     700    4000000
# 5     750    4500000
# 6     800    5000000
# 7     850    5500000
# 8     900    6000000
# 9     950    6500000
# 10   1500   54500000
# 11   1752    8500000
# 12   2105    7500000
# 13   2456    8540000
# 14   2973    6500000
# 15    245     500000
# 16    415    5500000
# 17    678    6552000
# 18   1257    6500500
# 19    952    6586000
# 20   6321   65009600
# 21   1545     652000
# 22   4562    7008560
# 23  74582      65000
# 24   9524     756920
# 25   4255   52600000
# 26  48552  650075985
# 27   6345   66500000
# 28   5285    6500045
# 29   4745    6500045

# %%
dataset.shape
# Out:
# (30, 2)

# %%
dataset.describe()
# Out:
#                Area         Price
# count     30.000000  3.000000e+01
# mean    6243.300000  3.364489e+07
# std    15587.727653  1.179953e+08
# min      245.000000  6.500000e+04
# 25%      712.500000  3.625000e+06
# 50%     1378.500000  6.500000e+06
# 75%     4485.250000  7.377140e+06
# max    74582.000000  6.500760e+08

# %%
x=dataset['Area']
y=dataset['Price']

# %%
x = dataset.iloc[:,0:1].values

# %%
x
# Out:
# array([[  500],
#        [  550],
#        [  600],
#        [  650],
#        [  700],
#        [  750],
#        [  800],
#        [  850],
#        [  900],
#        [  950],
#        [ 1500],
#        [ 1752],
#        [ 2105],
#        [ 2456],
#        [ 2973],
#        [  245],
#        [  415],
#        [  678],
#        [ 1257],
#        [  952],
#        [ 6321],
#        [ 1545],
#        [ 4562],
#        [74582],
#        [ 9524],
#        [ 4255],
#        [48552],
#        [ 6345],
#        [ 5285],
#        [ 4745]])

# %%
y = dataset.iloc[:,-1].values

# %%
y
# Out:
# array([  2000000,   2500000,   3000000,   3500000,   4000000,   4500000,
#          5000000,   5500000,   6000000,   6500000,  54500000,   8500000,
#          7500000,   8540000,   6500000,    500000,   5500000,   6552000,
#          6500500,   6586000,  65009600,    652000,   7008560,     65000,
#           756920,  52600000, 650075985,  66500000,   6500045,   6500045])

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2,random_state=10)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred_test=regressor.predict(x_test)

# %%
y_pred_test
# Out:
# array([34757416.50914077, 14304760.9125018 , 13930923.30335102,
#        13370166.88962486, 13557085.69420025, 16902932.29609969])

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred_test)
# Out:
# 0.5101560927423571

# %%
y_test
# Out:
# array([65009600,  5500000,  4500000,  3000000,  3500000,   652000])

# %%
plt.scatter(x_train,y_train, color = 'red')
plt.plot(x_train, regressor.predict(x_train), color='blue')

# %%
plt.scatter(x_test,y_test, color = 'red')
plt.plot(x_test, regressor.predict(x_test), color='blue')

# %%
y_pred_test=regressor.predict([[725]])
y_pred_test
# Out:
# array([13837463.90106333])
